# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_row',500)
pd.options.display.max_columns = 150

# %%
chk_size=300000

# %%
df_chunk=pd.read_csv('C:/Users/hp/Desktop/DSP/New folder (2)/Python/Credit risk/XYZCorp_Credit_Risk.csv',chunksize=chk_size,encoding='latin1')

# %%
chuck_list=[]

# %%
for i in df_chunk:
    chuck_list.append(i)

# %%
df=pd.DataFrame()

# %%
df=pd.concat(chuck_list)

# %%
df.shape
# Out:
# (855969, 73)

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# 2     15.96        84.33     C        C5                       NaN  10+ years
# 3     13.49       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4     12.69        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
df.dtypes
# Out:
# id                               int64
# member_id                        int64
# loan_amnt                        int64
# funded_amnt                      int64
# funded_amnt_inv                float64
# term                            object
# int_rate                       float64
# installment                    float64
# grade                           object
# sub_grade                       object
# emp_title                       object
# emp_length                      object
# home_ownership                  object
# annual_inc                     float64
# verification_status             object
# issue_d                         object
# pymnt_plan                      object
# desc                            object
# purpose                         object
# title                           object
# zip_code                        object
# addr_state                      object
# dti                            float64
# delinq_2yrs                      int64
# ...

# %%
df.describe(include='all')
# Out:
#                   id     member_id      loan_amnt    funded_amnt  \
# count   8.559690e+05  8.559690e+05  855969.000000  855969.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# mean    3.224073e+07  3.476269e+07   14745.571335   14732.378305
# std     2.271969e+07  2.399418e+07    8425.340005    8419.471653
# min     5.473400e+04  7.069900e+04     500.000000     500.000000
# 25%     9.067986e+06  1.079273e+07    8000.000000    8000.000000
# 50%     3.431355e+07  3.697532e+07   13000.000000   13000.000000
# 75%     5.446311e+07  5.803559e+07   20000.000000   20000.000000
# max     6.861687e+07  7.351969e+07   35000.000000   35000.000000
#
#         funded_amnt_inv        term       int_rate    installment   grade  \
# count     855969.000000      855969  855969.000000  855969.000000  855969
# ...

# %%
#The data is divided into train (June 2007 - May 2015) and test (June 2015 - Dec 2015) 
Train = df.loc[pd.to_datetime(df['issue_d'].str.upper(), format='%b-%y', yearfirst=False) <'2015-06-01']
Test =  df.loc[pd.to_datetime(df['issue_d'].str.upper(), format='%b-%y', yearfirst=False) >='2015-06-01']

# %%
Train.shape,Test.shape
# Out:
# ((598978, 73), (256991, 73))

# %%
Train.to_csv('C:/Users/hp/Desktop/DSP/New folder (2)/Python/Credit risk/Train_data.csv',index=False)
Test.to_csv('C:/Users/hp/Desktop/DSP/New folder (2)/Python/Credit risk/Test_data.csv',index=False)
